# %%
import pandas as pd

# %%
annotations_df = pd.read_csv('walcott_annotations_from_powerapp.csv')
annotations_df.head()
# Out:
#    Title  bhl_pageid          scientific_name       common_name  \
# 0    NaN    42667723      Prunus angustifolia    CHICKASAW PLUM
# 1    NaN    42602674  Liriodendron tulipifera         Tuliptree
# 2    NaN    42667749        Zygadenus elegans        Deathcamas
# 3    NaN    42669109        Tsuga mertensiana  Mountain Hemlock
# 4    NaN    42602678       Dodecatheon meadia     Shootingstar
#
#               author                                   geographic_range  \
# 0           Marshall  from Florida to southern New Jersey, and westw...
# 1           Linnaeus  eastern United States from Louisiana to Florid...
# 2              Pursh  mountains of Nevada and New Mexico and northwa...
# 3  (Bongard) Sargent           western Montana to California and Alaska
# 4           Linnaeus  Texas to Georgia, and northward into Manitoba;...
#
#                                    specimen_location altitude_feet  \
# 0              near Washington, District of Columbia           NaN
# 1                   Washington, District of Columbia           NaN
# 2  Clearwater River, thirty-five miles by trail n...          6500
# 3      near Glacier House, Glacier, British Columbia          3500
# 4              near Washington, District of Columbia           NaN
#
#                   colors_listed             Created       Created By  \
# 0                   red, yellow  11/21/2025 1:57 PM  Naples, Richard
# 1           green, orange, gold  11/21/2025 2:03 PM     Sobers, Kira
# 2  greenish white, bright green  11/21/2025 2:05 PM     Sobers, Kira
# 3                   dark green,  11/21/2025 2:06 PM     Sobers, Kira
# 4                           red  11/21/2025 2:08 PM     Sobers, Kira
#
#   [annotation notes]
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN

# %%
annotations_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 167 entries, 0 to 166
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Title               0 non-null      float64
#  1   bhl_pageid          167 non-null    int64
#  2   scientific_name     167 non-null    object
#  3   common_name         167 non-null    object
#  4   author              167 non-null    object
#  5   geographic_range    166 non-null    object
#  6   specimen_location   159 non-null    object
#  7   altitude_feet       84 non-null     object
#  8   colors_listed       120 non-null    object
#  9   Created             167 non-null    object
#  10  Created By          167 non-null    object
#  11  [annotation notes]  16 non-null     object
# dtypes: float64(1), int64(1), object(10)
# memory usage: 15.8+ KB

# %%
annotations_df['bhl_pageid'] = annotations_df['bhl_pageid'].astype(str)

# %%
import json
from pathlib import Path

# %%
model_dirs = {
    "Qwen3-0.6b": Path("qwen06"),
    "Qwen3-1.7b": Path("qwen17"),
    "Qwen3-4b": Path("Qwen3-4B-Instruct-2507"),
    "Qwen3-8b": Path("qwen8b"),
    "Qwen3-14b": Path("qwen14b"),
    "Qwen3-32b": Path("qwen32b"),
}

# %%
records = []
for model_name, dir_path in model_dirs.items():
    for json_file in dir_path.glob("*.json"):
        pageid = json_file.stem
        with open(json_file) as f:
            data = json.load(f)
        data["bhl_pageid"] = pageid
        data["model"] = model_name
        records.append(data)
predictions_df = pd.DataFrame(records)
predictions_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2352 entries, 0 to 2351
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   plate_number       2352 non-null   object
#  1   common_name        2352 non-null   object
#  2   scientific_name    2352 non-null   object
#  3   author             2352 non-null   object
#  4   altitude_feet      2352 non-null   object
#  5   geographic_range   2352 non-null   object
#  6   specimen_location  2352 non-null   object
#  7   colors_listed      2352 non-null   object
#  8   bhl_pageid         2352 non-null   object
#  9   model              2352 non-null   object
# dtypes: object(10)
# memory usage: 183.9+ KB

# %%
merged = predictions_df.merge(annotations_df, on="bhl_pageid", suffixes=("_pred", "_gt"))
merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1002 entries, 0 to 1001
# Data columns (total 21 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   plate_number            1002 non-null   object
#  1   common_name_pred        1002 non-null   object
#  2   scientific_name_pred    1002 non-null   object
#  3   author_pred             1002 non-null   object
#  4   altitude_feet_pred      1002 non-null   object
#  5   geographic_range_pred   1002 non-null   object
#  6   specimen_location_pred  1002 non-null   object
#  7   colors_listed_pred      1002 non-null   object
#  8   bhl_pageid              1002 non-null   object
#  9   model                   1002 non-null   object
#  10  Title                   0 non-null      float64
#  11  scientific_name_gt      1002 non-null   object
#  12  common_name_gt          1002 non-null   object
#  13  author_gt               1002 non-null   object
#  14  geographic_range_gt     996 non-null    object
#  15  specimen_location_gt    954 non-null    object
#  16  altitude_feet_gt        504 non-null    object
#  17  colors_listed_gt        720 non-null    object
#  18  Created                 1002 non-null   object
#  19  Created By              1002 non-null   object
#  20  [annotation notes]      96 non-null     object
# dtypes: float64(1), object(20)
# memory usage: 164.5+ KB

# %%
def normalize(s):
    if pd.isna(s):
        return ""
    return str(s).strip().lower()

# %%
merged["common_name_pred_norm"] = merged["common_name_pred"].apply(normalize)
merged["common_name_gt_norm"] = merged["common_name_gt"].apply(normalize)
merged["common_name_match"] = merged["common_name_pred_norm"] == merged["common_name_gt_norm"]

merged.groupby("model")["common_name_match"].mean()
# Out:
# model
# Qwen3-0.6b    0.814371
# Qwen3-1.7b    0.850299
# Qwen3-14b     0.982036
# Qwen3-32b     0.982036
# Qwen3-4b      0.970060
# Qwen3-8b      0.976048
# Name: common_name_match, dtype: float64

# %%
mismatches = merged[~merged["common_name_match"]][["bhl_pageid", "model", "common_name_pred_norm", "common_name_gt_norm"]]
mismatches.head(10)
# Out:
#    bhl_pageid       model       common_name_pred_norm  \
# 3    42669668  Qwen3-0.6b                   fremontia
# 4    42667748  Qwen3-0.6b       amelanchier alnifolia
# 7    42669351  Qwen3-0.6b  salix drummondiana barratt
# 12   42602668  Qwen3-0.6b       viola pedata linnaeus
# 17   42667744  Qwen3-0.6b           achillea lanulosa
# 18   42667713  Qwen3-0.6b         oxytropis splendens
# 19   42669127  Qwen3-0.6b              pyrola secunda
# 23   42667801  Qwen3-0.6b     loyds strawberry-cactus
# 31   42602673  Qwen3-0.6b           cracca virginiana
# 34   42669674  Qwen3-0.6b                 cyrtopodium
#
#          common_name_gt_norm
# 3          mexican fremontia
# 4                  saskatoon
# 7            drummond willow
# 12          birdsfoot violet
# 17            western yarrow
# 18            showy oxytrope
# 19          sidebells pyrola
# 23  lloyds strawberry-cactus
# 31                rabbitbean
# 34       spotted cyrtopodium

# %%
def calculate_accuracy(merged_df, column):
    """Calculate exact-match accuracy for a column across models."""
    pred_col = f"{column}_pred"
    gt_col = f"{column}_gt"
    match_col = f"{column}_match"
    
    pred_norm = merged_df[pred_col].apply(normalize)
    gt_norm = merged_df[gt_col].apply(normalize)
    merged_df[match_col] = pred_norm == gt_norm
    
    return merged_df.groupby("model")[match_col].mean()

# %%
for col in ["common_name", "scientific_name", "author"]:
    print(f"\n{col}:")
    print(calculate_accuracy(merged, col))
# Out:
# common_name:
# model
# Qwen3-0.6b    0.814371
# Qwen3-1.7b    0.850299
# Qwen3-14b     0.982036
# Qwen3-32b     0.982036
# Qwen3-4b      0.970060
# Qwen3-8b      0.976048
# Name: common_name_match, dtype: float64
#
# scientific_name:
# model
# Qwen3-0.6b    0.251497
# Qwen3-1.7b    0.502994
# Qwen3-14b     0.994012
# Qwen3-32b     0.994012
# Qwen3-4b      0.976048
# Qwen3-8b      0.928144
# Name: scientific_name_match, dtype: float64
#
# author:
# model
# Qwen3-0.6b    0.670659
# Qwen3-1.7b    0.670659
# Qwen3-14b     0.700599
# Qwen3-32b     0.700599
# Qwen3-4b      0.700599
# Qwen3-8b      0.712575
# Name: author_match, dtype: float64

# %%
import re

def tokenize(s):
    """Normalize and split into word set."""
    if pd.isna(s):
        return set()
    # Lowercase, remove punctuation, split into words
    s = str(s).lower()
    s = re.sub(r'[^\w\s]', '', s)  # Remove punctuation
    return set(s.split())

def word_difference(s1, s2):
    """Count words that differ between two strings."""
    words1 = tokenize(s1)
    words2 = tokenize(s2)
    return len(words1.symmetric_difference(words2))

def calculate_fuzzy_accuracy(merged_df, column, max_diff=2):
    """Calculate accuracy allowing up to max_diff word differences."""
    pred_col = f"{column}_pred"
    gt_col = f"{column}_gt"
    match_col = f"{column}_match"
    diff_col = f"{column}_diff"
    
    merged_df[diff_col] = merged_df.apply(
        lambda row: word_difference(row[pred_col], row[gt_col]), 
        axis=1
    )
    merged_df[match_col] = merged_df[diff_col] <= max_diff
    
    return merged_df.groupby("model")[match_col].mean()

# Run it
for col in ["geographic_range", "specimen_location"]:
    print(f"\n{col} (max 2 words different):")
    print(calculate_fuzzy_accuracy(merged, col, max_diff=2))
# Out:
# geographic_range (max 2 words different):
# model
# Qwen3-0.6b    0.754491
# Qwen3-1.7b    0.772455
# Qwen3-14b     0.850299
# Qwen3-32b     0.808383
# Qwen3-4b      0.814371
# Qwen3-8b      0.814371
# Name: geographic_range_match, dtype: float64
#
# specimen_location (max 2 words different):
# model
# Qwen3-0.6b    0.556886
# Qwen3-1.7b    0.826347
# Qwen3-14b     0.910180
# Qwen3-32b     0.904192
# Qwen3-4b      0.892216
# Qwen3-8b      0.898204
# Name: specimen_location_match, dtype: float64

# %%
merged["geographic_range_diff"].value_counts().sort_index().head(10)
# Out:
# geographic_range_diff
# 0    395
# 1    318
# 2     91
# 3     48
# 4     15
# 5      7
# 6     31
# 7     11
# 8     13
# 9      6
# Name: count, dtype: int64

# %%
def parse_colors(s):
    """Parse comma-separated colors into a normalized set."""
    if pd.isna(s) or str(s).strip() == "":
        return set()
    # Split on comma, strip whitespace, lowercase, remove empty strings
    colors = [c.strip().lower() for c in str(s).split(",")]
    return set(c for c in colors if c)  # Filter out empty strings

def calculate_set_accuracy(merged_df, column):
    """Calculate exact set match accuracy."""
    pred_col = f"{column}_pred"
    gt_col = f"{column}_gt"
    match_col = f"{column}_match"
    
    merged_df[f"{column}_pred_set"] = merged_df[pred_col].apply(parse_colors)
    merged_df[f"{column}_gt_set"] = merged_df[gt_col].apply(parse_colors)
    merged_df[match_col] = merged_df[f"{column}_pred_set"] == merged_df[f"{column}_gt_set"]
    
    return merged_df.groupby("model")[match_col].mean()

print("colors_listed (exact set match):")
print(calculate_set_accuracy(merged, "colors_listed"))
# Out:
# colors_listed (exact set match):
# model
# Qwen3-0.6b    0.179641
# Qwen3-1.7b    0.335329
# Qwen3-14b     0.514970
# Qwen3-32b     0.598802
# Qwen3-4b      0.479042
# Qwen3-8b      0.502994
# Name: colors_listed_match, dtype: float64

# %%
def normalize_altitude(s):
    """Normalize altitude: remove commas, 'feet', and whitespace."""
    if pd.isna(s) or str(s).strip() == "":
        return ""
    s = str(s).lower()
    s = s.replace(",", "")      # Remove commas
    s = s.replace("feet", "")   # Remove "feet"
    s = s.strip()
    return s

def calculate_altitude_accuracy(merged_df):
    """Calculate exact match accuracy for altitude_feet."""
    merged_df["altitude_feet_pred_norm"] = merged_df["altitude_feet_pred"].apply(normalize_altitude)
    merged_df["altitude_feet_gt_norm"] = merged_df["altitude_feet_gt"].apply(normalize_altitude)
    merged_df["altitude_feet_match"] = merged_df["altitude_feet_pred_norm"] == merged_df["altitude_feet_gt_norm"]
    
    return merged_df.groupby("model")["altitude_feet_match"].mean()

print("altitude_feet:")
print(calculate_altitude_accuracy(merged))
# Out:
# altitude_feet:
# model
# Qwen3-0.6b    0.568862
# Qwen3-1.7b    0.976048
# Qwen3-14b     0.922156
# Qwen3-32b     0.970060
# Qwen3-4b      0.976048
# Qwen3-8b      0.982036
# Name: altitude_feet_match, dtype: float64

# %%
# All match columns we created
match_cols = [
    "common_name_match",
    "scientific_name_match",
    "author_match",
    "geographic_range_match",
    "specimen_location_match",
    "altitude_feet_match",
    "colors_listed_match"
]

# Accuracy per field per model
accuracy_summary = merged.groupby("model")[match_cols].mean()

# Rename columns to remove "_match" suffix for cleaner display
accuracy_summary.columns = [col.replace("_match", "") for col in accuracy_summary.columns]

# Add overall average across all fields
accuracy_summary["overall"] = accuracy_summary.mean(axis=1)

print(accuracy_summary.round(3))
# Out:
#             common_name  scientific_name  author  geographic_range  \
# model
# Qwen3-0.6b        0.814            0.251   0.671             0.754
# Qwen3-1.7b        0.850            0.503   0.671             0.772
# Qwen3-14b         0.982            0.994   0.701             0.850
# Qwen3-32b         0.982            0.994   0.701             0.808
# Qwen3-4b          0.970            0.976   0.701             0.814
# Qwen3-8b          0.976            0.928   0.713             0.814
#
#             specimen_location  altitude_feet  colors_listed  overall
# model
# Qwen3-0.6b              0.557          0.569          0.180    0.542
# Qwen3-1.7b              0.826          0.976          0.335    0.705
# Qwen3-14b               0.910          0.922          0.515    0.839
# Qwen3-32b               0.904          0.970          0.599    0.851
# Qwen3-4b                0.892          0.976          0.479    0.830
# Qwen3-8b                0.898          0.982          0.503    0.831

# %%
model_order = [
    "Qwen3-0.6b",
    "Qwen3-1.7b",
    "Qwen3-4b",
    "Qwen3-8b",
    "Qwen3-14b",
    "Qwen3-32b",    
]

accuracy_summary = accuracy_summary.reindex(model_order)

# %%
styled = accuracy_summary.style \
    .bar(axis=None, cmap='RdYlGn', vmin=0, vmax=1) \
    .format("{:.1%}") \
    .set_properties(**{
        'text-align': 'left',
        'padding-left': '5px'
    })

styled
# Out:
# <style type="text/css">
# #T_2b142_row0_col0, #T_2b142_row2_col3, #T_2b142_row3_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #5ab760 81.4%, transparent 81.4%);
#   text-align: left;
#   padding-left: 5px;
# }
# #T_2b142_row0_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #f98e52 25.1%, transparent 25.1%);
#   text-align: left;
#   padding-left: 5px;
# }
# #T_2b142_row0_col2, #T_2b142_row1_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b5df74 67.1%, transparent 67.1%);
#   text-align: left;
#   padding-left: 5px;
# }
# #T_2b142_row0_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #82c966 75.4%, transparent 75.4%);
#   text-align: left;
#   padding-left: 5px;
# }
# #T_2b142_row0_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #e9f6a1 55.7%, transparent 55.7%);
#   text-align: left;
#   padding-left: 5px;
# }
# #T_2b142_row0_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #e5f49b 56.9%, transparent 56.9%);
#   text-align: left;
#   padding-left: 5px;
# }
# #T_2b142_row0_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, #ed5f3c 18.0%, transparent 18.0%);
#   text-align: left;
#   padding-left: 5px;
# }
# #T_2b142_row0_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, #eff8aa 54.2%, transparent 54.2%);
#   text-align: left;
#   padding-left: 5px;
# }
# #T_2b142_row1_col0, #T_2b142_row4_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #3faa59 85.0%, transparent 85.0%);
#   text-align: left;
#   padding-left: 5px;
# }
# #T_2b142_row1_col1, #T_2b142_row3_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, #feffbe 50.3%, transparent 50.3%);
#   text-align: left;
#   padding-left: 5px;
# }
# #T_2b142_row1_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #78c565 77.2%, transparent 77.2%);
#   text-align: left;
#   padding-left: 5px;
# }
# #T_2b142_row1_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #51b35e 82.6%, transparent 82.6%);
#   text-align: left;
#   padding-left: 5px;
# }
# #T_2b142_row1_col5, #T_2b142_row2_col1, #T_2b142_row2_col5, #T_2b142_row3_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #06733d 97.6%, transparent 97.6%);
#   text-align: left;
#   padding-left: 5px;
# }
# #T_2b142_row1_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, #fdbf6f 33.5%, transparent 33.5%);
#   text-align: left;
#   padding-left: 5px;
# }
# #T_2b142_row1_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, #a2d76a 70.5%, transparent 70.5%);
#   text-align: left;
#   padding-left: 5px;
# }
# #T_2b142_row2_col0, #T_2b142_row5_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #07753e 97.0%, transparent 97.0%);
#   text-align: left;
#   padding-left: 5px;
# }
# #T_2b142_row2_col2, #T_2b142_row4_col2, #T_2b142_row5_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #a5d86a 70.1%, transparent 70.1%);
#   text-align: left;
#   padding-left: 5px;
# }
# #T_2b142_row2_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #1e9a51 89.2%, transparent 89.2%);
#   text-align: left;
#   padding-left: 5px;
# }
# #T_2b142_row2_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, #fff8b4 47.9%, transparent 47.9%);
#   text-align: left;
#   padding-left: 5px;
# }
# #T_2b142_row2_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, #4eb15d 83.0%, transparent 83.0%);
#   text-align: left;
#   padding-left: 5px;
# }
# #T_2b142_row3_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #128a49 92.8%, transparent 92.8%);
#   text-align: left;
#   padding-left: 5px;
# }
# #T_2b142_row3_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #9dd569 71.3%, transparent 71.3%);
#   text-align: left;
#   padding-left: 5px;
# }
# #T_2b142_row3_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #1b9950 89.8%, transparent 89.8%);
#   text-align: left;
#   padding-left: 5px;
# }
# #T_2b142_row3_col5, #T_2b142_row4_col0, #T_2b142_row5_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #04703b 98.2%, transparent 98.2%);
#   text-align: left;
#   padding-left: 5px;
# }
# #T_2b142_row3_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, #4eb15d 83.1%, transparent 83.1%);
#   text-align: left;
#   padding-left: 5px;
# }
# #T_2b142_row4_col1, #T_2b142_row5_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #016a38 99.4%, transparent 99.4%);
#   text-align: left;
#   padding-left: 5px;
# }
# #T_2b142_row4_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #16914d 91.0%, transparent 91.0%);
#   text-align: left;
#   padding-left: 5px;
# }
# #T_2b142_row4_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #138c4a 92.2%, transparent 92.2%);
#   text-align: left;
#   padding-left: 5px;
# }
# #T_2b142_row4_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, #fafdb8 51.5%, transparent 51.5%);
#   text-align: left;
#   padding-left: 5px;
# }
# #T_2b142_row4_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, #48ae5c 83.9%, transparent 83.9%);
#   text-align: left;
#   padding-left: 5px;
# }
# #T_2b142_row5_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #60ba62 80.8%, transparent 80.8%);
#   text-align: left;
#   padding-left: 5px;
# }
# #T_2b142_row5_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #18954f 90.4%, transparent 90.4%);
#   text-align: left;
#   padding-left: 5px;
# }
# #T_2b142_row5_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, #d9ef8b 59.9%, transparent 59.9%);
#   text-align: left;
#   padding-left: 5px;
# }
# #T_2b142_row5_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, #3faa59 85.1%, transparent 85.1%);
#   text-align: left;
#   padding-left: 5px;
# }
# </style>
# <table id="T_2b142">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2b142_level0_col0" class="col_heading level0 col0" >common_name</th>
#       <th id="T_2b142_level0_col1" class="col_heading level0 col1" >scientific_name</th>
#       <th id="T_2b142_level0_col2" class="col_heading level0 col2" >author</th>
#       <th id="T_2b142_level0_col3" class="col_heading level0 col3" >geographic_range</th>
#       <th id="T_2b142_level0_col4" class="col_heading level0 col4" >specimen_location</th>
#       <th id="T_2b142_level0_col5" class="col_heading level0 col5" >altitude_feet</th>
#       <th id="T_2b142_level0_col6" class="col_heading level0 col6" >colors_listed</th>
#       <th id="T_2b142_level0_col7" class="col_heading level0 col7" >overall</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >model</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2b142_level0_row0" class="row_heading level0 row0" >Qwen3-0.6b</th>
#       <td id="T_2b142_row0_col0" class="data row0 col0" >81.4%</td>
#       <td id="T_2b142_row0_col1" class="data row0 col1" >25.1%</td>
#       <td id="T_2b142_row0_col2" class="data row0 col2" >67.1%</td>
#       <td id="T_2b142_row0_col3" class="data row0 col3" >75.4%</td>
#       <td id="T_2b142_row0_col4" class="data row0 col4" >55.7%</td>
#       <td id="T_2b142_row0_col5" class="data row0 col5" >56.9%</td>
#       <td id="T_2b142_row0_col6" class="data row0 col6" >18.0%</td>
#       <td id="T_2b142_row0_col7" class="data row0 col7" >54.2%</td>
#     </tr>
#     <tr>
#       <th id="T_2b142_level0_row1" class="row_heading level0 row1" >Qwen3-1.7b</th>
#       <td id="T_2b142_row1_col0" class="data row1 col0" >85.0%</td>
#       <td id="T_2b142_row1_col1" class="data row1 col1" >50.3%</td>
#       <td id="T_2b142_row1_col2" class="data row1 col2" >67.1%</td>
#       <td id="T_2b142_row1_col3" class="data row1 col3" >77.2%</td>
#       <td id="T_2b142_row1_col4" class="data row1 col4" >82.6%</td>
#       <td id="T_2b142_row1_col5" class="data row1 col5" >97.6%</td>
#       <td id="T_2b142_row1_col6" class="data row1 col6" >33.5%</td>
#       <td id="T_2b142_row1_col7" class="data row1 col7" >70.5%</td>
#     </tr>
#     <tr>
#       <th id="T_2b142_level0_row2" class="

# %%
styled = accuracy_summary.style \
    .bar(axis=None, cmap='RdYlGn', vmin=0, vmax=1) \
    .format("{:.1%}") \
    .set_properties(**{
        'text-align': 'left',
        'padding-left': '5px',
        'color': 'white',
        'text-shadow': '1px 1px 2px black'
    })

styled
# Out:
# <style type="text/css">
# #T_49469_row0_col0, #T_49469_row2_col3, #T_49469_row3_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #5ab760 81.4%, transparent 81.4%);
#   text-align: left;
#   padding-left: 5px;
#   color: white;
#   text-shadow: 1px 1px 2px black;
# }
# #T_49469_row0_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #f98e52 25.1%, transparent 25.1%);
#   text-align: left;
#   padding-left: 5px;
#   color: white;
#   text-shadow: 1px 1px 2px black;
# }
# #T_49469_row0_col2, #T_49469_row1_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b5df74 67.1%, transparent 67.1%);
#   text-align: left;
#   padding-left: 5px;
#   color: white;
#   text-shadow: 1px 1px 2px black;
# }
# #T_49469_row0_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #82c966 75.4%, transparent 75.4%);
#   text-align: left;
#   padding-left: 5px;
#   color: white;
#   text-shadow: 1px 1px 2px black;
# }
# #T_49469_row0_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #e9f6a1 55.7%, transparent 55.7%);
#   text-align: left;
#   padding-left: 5px;
#   color: white;
#   text-shadow: 1px 1px 2px black;
# }
# #T_49469_row0_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #e5f49b 56.9%, transparent 56.9%);
#   text-align: left;
#   padding-left: 5px;
#   color: white;
#   text-shadow: 1px 1px 2px black;
# }
# #T_49469_row0_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, #ed5f3c 18.0%, transparent 18.0%);
#   text-align: left;
#   padding-left: 5px;
#   color: white;
#   text-shadow: 1px 1px 2px black;
# }
# #T_49469_row0_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, #eff8aa 54.2%, transparent 54.2%);
#   text-align: left;
#   padding-left: 5px;
#   color: white;
#   text-shadow: 1px 1px 2px black;
# }
# #T_49469_row1_col0, #T_49469_row4_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #3faa59 85.0%, transparent 85.0%);
#   text-align: left;
#   padding-left: 5px;
#   color: white;
#   text-shadow: 1px 1px 2px black;
# }
# #T_49469_row1_col1, #T_49469_row3_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, #feffbe 50.3%, transparent 50.3%);
#   text-align: left;
#   padding-left: 5px;
#   color: white;
#   text-shadow: 1px 1px 2px black;
# }
# #T_49469_row1_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #78c565 77.2%, transparent 77.2%);
#   text-align: left;
#   padding-left: 5px;
#   color: white;
#   text-shadow: 1px 1px 2px black;
# }
# #T_49469_row1_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #51b35e 82.6%, transparent 82.6%);
#   text-align: left;
#   padding-left: 5px;
#   color: white;
#   text-shadow: 1px 1px 2px black;
# }
# #T_49469_row1_col5, #T_49469_row2_col1, #T_49469_row2_col5, #T_49469_row3_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #06733d 97.6%, transparent 97.6%);
#   text-align: left;
#   padding-left: 5px;
#   color: white;
#   text-shadow: 1px 1px 2px black;
# }
# #T_49469_row1_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, #fdbf6f 33.5%, transparent 33.5%);
#   text-align: left;
#   padding-left: 5px;
#   color: white;
#   text-shadow: 1px 1px 2px black;
# }
# #T_49469_row1_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, #a2d76a 70.5%, transparent 70.5%);
#   text-align: left;
#   padding-left: 5px;
#   color: white;
#   text-shadow: 1px 1px 2px black;
# }
# #T_49469_row2_col0, #T_49469_row5_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #07753e 97.0%, transparent 97.0%);
#   text-align: left;
#   padding-left: 5px;
#   color: white;
#   text-shadow: 1px 1px 2px black;
# }
# #T_49469_row2_col2, #T_49469_row4_col2, #T_49469_row5_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #a5d86a 70.1%, transparent 70.1%);
#   text-align: left;
#   padding-left: 5px;
#   color: white;
#   text-shadow: 1px 1px 2px black;
# }
# #T_49469_row2_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #1e9a51 89.2%, transparent 89.2%);
#   text-align: left;
#   padding-left: 5px;
#   color: white;
#   text-shadow: 1px 1px 2px black;
# }
# #T_49469_row2_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, #fff8b4 47.9%, transparent 47.9%);
#   text-align: left;
#   padding-left: 5px;
#   color: white;
#   text-shadow: 1px 1px 2px black;
# }
# #T_49469_row2_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, #4eb15d 83.0%, transparent 83.0%);
#   text-align: left;
#   padding-left: 5px;
#   color: white;
#   text-shadow: 1px 1px 2px black;
# }
# #T_49469_row3_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #128a49 92.8%, transparent 92.8%);
#   text-align: left;
#   padding-left: 5px;
#   color: white;
#   text-shadow: 1px 1px 2px black;
# }
# #T_49469_row3_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #9dd569 71.3%, transparent 71.3%);
#   text-align: left;
#   padding-left: 5px;
#   color: white;
#   text-shadow: 1px 1px 2px black;
# }
# #T_49469_row3_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #1b9950 89.8%, transparent 89.8%);
#   text-align: left;
#   padding-left: 5px;
#   color: white;
#   text-shadow: 1px 1px 2px black;
# }
# #T_49469_row3_col5, #T_49469_row4_col0, #T_49469_row5_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #04703b 98.2%, transparent 98.2%);
#   text-align: left;
#   padding-left: 5px;
#   color: white;
#   text-shadow: 1px 1px 2px black;
# }
# #T_49469_row3_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, #4eb15d 83.1%, transparent 83.1%);
#   text-align: left;
#   padding-left: 5px;
#   color: white;
#   text-shadow: 1px 1px 2px black;
# }
# #T_49469_row4_col1, #T_49469_row5_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #016a38 99.4%, transparent 99.4%);
#   text-align: left;
#   padding-left: 5px;
#   color: white;
#   text-shadow: 1px 1px 2px black;
# }
# #T_49469_row4_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #16914d 91.0%, transparent 91.0%);
#   text-align: left;
#   padding-left: 5px;
#   color: white;
#   text-shadow: 1px 1px 2px black;
# }
# #T_49469_row4_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #138c4a 92.2%, transparent 92.2%);
#   text-align: left;
#   padding-left: 5px;
#   color: white;
#   text-shadow: 1px 1px 2px black;
# }
# #T_49469_row4_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, #fafdb8 51.5%, transparent 51.5%);
#   text-align: left;
#   padding-left: 5px;
#   color: white;
#   text-shadow: 1px 1px 2px black;
# }
# #T_49469_row4_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, #48ae5c 83.9%, transparent 83.9%);
#   text-align: left;
#   padding-left: 5px;
#   color: white;
#   text-shadow: 1px 1px 2px black;
# }
# #T_49469_row5_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #60ba62 80.8%, transparent 80.8%);
#   text-align: left;
#   padding-left: 5px;
#   color: white;
#   text-shadow: 1px 1px 2px black;
# }
# #T_49469_row5_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #18954f 90.4%, transparent 90.4%);
#   text-align: left;
#   padding-left: 5px;
#   color: white;
#   text-shadow: 1px 1px 2px black;
# }
# #T_49469_row5_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, #d9ef8b 59.9%, transparent 59.9%);
#   text-align: left;
#   padding-left: 5px;
#   color: white;
#   text-shadow: 1px 1px 2px black;
# }
# #T_49469_row5_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, #3faa59 85.1%, transparent 85.1%);
#   text-align: left;
#   padding-left: 5px;
#   color: white;
#   text-shadow: 1px 1px 2px black;
# }
# </style>
# <table id="T_49469">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_49469_level0_col0" class="col_heading level0 col0" >common_name</th>
#       <th id="T_49469_level0_col1" class="col_heading level0 col1" >scientific_name</th>
#       <th id="T_49469_level0_col2" class="col_heading level0 col2" >author</th>
#       <th id="T_49469_level0_col3" class="col_heading level0 col3" >geographic_range</th>
#       <th id="T_49469_level0_col4" class="col_heading level0 col4" >specimen_location</th>
#       <th id="T_49469_level0_col5" class="col_heading level0 col5" >altitude_feet</th>
#       <th id="T_49469_level0_col6" class="col_heading level0 col6" >colors_listed</th>
#       <th id="T_49469_level0_col7" class="col_heading level0 col7" >overall</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >model</th>
#       <th cl

# %%
styled.to_html("qwen3_accuracy_table.html")
